# %%
import json

# Replace 'your_file.json' with the path to your JSON file
file_path = 'datasets/openvivqa/openvivqa_dev_data.json'

with open(file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
file_path_b = 'datasets/vitextvqa/vitextvqa_dev_data.json'

with open(file_path_b, 'r', encoding='utf-8') as file:
    data_b = json.load(file)

# %%
question_id_a = [data[i]['question_id'] for i in range(len(data))]
question_id_b = [data_b[i]['question_id'] for i in range(len(data_b))]

# %%
common_question_ids = set(question_id_a).intersection(question_id_b)
print(common_question_ids)
# Out:
# {4103, 24632, 8259, 16452, 20547, 20550, 6221, 8280, 109, 28788, 139, 12427, 18578, 14486, 6300, 20642, 32932, 6310, 14502, 18600, 4267, 34987, 4271, 22705, 6322, 18615, 4283, 8386, 14531, 4305, 24788, 37076, 37086, 37087, 32999, 33001, 26859, 8435, 8437, 37109, 248, 2297, 33016, 267, 28939, 20754, 33047, 24861, 8478, 24871, 6444, 12609, 18755, 10567, 18759, 18762, 348, 2396, 2397, 31068, 16739, 14697, 10602, 4459, 24940, 8559, 10607, 37232, 26997, 16758, 22909, 29066, 29068, 33166, 29072, 403, 18836, 31123, 31125, 31126, 24986, 412, 414, 33183, 22966, 12727, 12728, 35260, 10723, 27118, 35323, 8706, 6667, 33295, 33297, 8731, 18974, 29225, 27185, 23091, 23095, 33355, 33356, 8781, 21069, 25172, 10838, 19040, 37474, 611, 35441, 35442, 35443, 4726, 8830, 21141, 27288, 33435, 21149, 21151, 33445, 33447, 2729, 6828, 10926, 6831, 19126, 35518, 37572, 2760, 37576, 4820, 4823, 15074, 8940, 2814, 33534, 31490, 31492, 25350, 15122, 23316, 17179, 2851, 2852, 23348, 4917, 29498, 9019, 9020, 37696
# ...

# %%
file_path = 'datasets/openvivqa/openvivqa_dev_data.json'

with open(file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
from PIL import Image

question_id = 88888815920

for item in data:
    if item['question_id'] == question_id:
        print(item['question'])
        image_path = 'datasets/openvivqa/' + item['image']
        image = Image.open(image_path)
        image.show()
        break
# Out:
# chợ này ở phường nào ?
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=660x441>
